# %%
# Paso 1: Importamos la librería pandas para hcer análisis de datos
import pandas as pd

# %%
# Paso 2: Se lee el archivo CSV y se convierte en un DataFrame
df = pd.read_csv('financials.csv', sep=',')
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
# Paso 3: Se realiza un análisis univariado de la columna "Price" usando el método describe()
df['Price'].describe()
# Out:
# count     505.000000
# mean      103.830634
# std       134.427636
# min         2.820000
# 25%        46.250000
# 50%        73.920000
# 75%       116.540000
# max      1806.060000
# Name: Price, dtype: float64

# %%
# Paso 4: Importamos las bibliotecas necesarias para visualizar los datos
import matplotlib.pyplot as plt

# %%
df['Price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# El dataset usado contiene numerosos indicadores financieros de las compañías que componen el S&P 500. Se descargó de Kaggle del siguiente enlace: https://www.kaggle.com/datasets/paytonfisher/sp-500-companies-with-financial-information.
#
# Para el ejercicio "Taller 2. Comparte tu Análisis univariado", escogí el campo 'Price', que corresponde al precio de una acción de cada empresa en el S&P 500 al momento de tomar los datos. Los datos fueron actualizados por últimas vez a julio de 2020.
#
# Análisis univariado:
# Empresas (count = 505): Se analizaron los precios de las acciones de 505 empresas que componen el índice S&P 500.
# Promedio (mean = 103.83): El precio promedio de las acciones de estas empresas es de 103.83 dólares.
# Desviación estándar (std = 134.43): Existe una alta variabilidad en los precios de las acciones, con una desviación estándar de 134.43 dólares, lo que indica que los precios están dispersos alrededor de la media.
# Mínimo (min = 2.82): El precio más bajo registrado entre las acciones fue de 2.82 dólares.
# Percentil 25 (25% = 46.25): El 25% de las acciones tiene un precio inferior a 46.25 dólares.
# Mediana (50% = 73.92): El precio mediano, que divide a las empresas en dos mitades, es de 73.92 dólares.
# Percentil 75 (75% = 116.54): El 75% de las acciones tiene un precio inferior a 116.54 dólares.
# Máximo (max = 1806.06): El precio más alto registrado es de 1806.06 dólares, reflejando que algunas acciones tienen un valor significativamente mayor en comparación con otras dentro del índice.
#
# Conclusión del gráfico: del histograma de la serie de precios, podemos ver que la mayor cantidad de empresas tienen un precio por acción menor a 250 dólares.
