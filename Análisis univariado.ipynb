# %%
# Paso 1: Importar las bibliotecas necesarias
import pandas as pd

# Paso 2: Leer el archivo CSV e importarlo en un DataFrame
df = pd.read_csv('apple_income_statement.csv')
df

# Paso 3: Transponer el DataFrame para que las columnas se conviertan en filas y las filas en columnas
df1 = df.transpose()
df1

# Paso 3: Se realiza un análisis univariado de la columna "Total Assets" usando el método describe()
#print(df['Total Assets'].describe())
# Out:
#               0                   1                       2   \
# Unnamed: 0  Cash  Cash & Equivalents  Short Term Investments
# 2012-12-31     0                5490                      29
# 2013-12-31     0                6081                      14
# 2014-12-31     0                7341                       0
# 2015-12-31     0                6460                       0
# 2016-12-31     0                7168                       0
# 2017-12-31     0                8261                       0
# 2018-12-31     0                7857                       1
# 2019-12-31     0                8284                       0
# 2020-12-31     0                9352                       0
# 2021-12-31     0                9254                       0
#
#                                          3                                 4   \
# Unnamed: 0  Cash and Short Term Investments  Accounts Receivable - Trade, Net
# ...
