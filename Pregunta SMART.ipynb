# %% [markdown]
# Predicción y prevención de la deserción de Tarjetas Crédito en un banco
# Usando la Ciencia de Datos, quiero identificar las principales características que determinan si un cliente va a cancelar su/s plástico/s emitido por el banco.
#
# ¿Cuáles características recolectadas y almacenadas en la bodega de datos del banco relacionadas al producto Tarjeta de Crédito y otros productos son las más significativas en determinar que un cliente con Tarjeta de Crédito vaya a cancerlar su plástico?
