# %% [markdown]
# ### Predicción y prevención del alto indice de deserción de Tarjetas Crédito en un banco.
# Usando la Ciencia de Datos, quiero identificar las principales características que determinan si un cliente va a cancelar su/s plástico/s emitido/s por el banco y desarrollar un modelo predictivo que permita identificar con anticipación a estos clientes para tomar acciones preventivas con el propósito de aumentar la vida del producto y la rentabilidad del banco a través de una mayor facturación y saldos.
# ¿Cuáles características recolectadas y almacenadas en la bodega de datos del banco relacionadas al producto Tarjeta de Crédito y otros productos ofrecidos por el banco son las más significativas en determinar que un cliente con Tarjeta de Crédito vaya a cancelar su plástico?

# %% [markdown]
# #### Pregunta SMART: ¿cuáles son los clientes que tienen la probabilidad más alta de cancelar su plástico en el siguiente mes de facturación?
