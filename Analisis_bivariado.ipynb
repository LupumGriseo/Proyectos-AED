# %%
# Paso 1: Importamos librerías para análisis de datos y visualización
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Paso 2: Se lee el archivo CSV y se convierte en un DataFrame
df = pd.read_csv('financials.csv', sep = ',')
df.head(5)
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  1.387211e+11
# 1        1.147959            1.70        68.39        48.925  1.078342e+10
# 2        1.908982            0.26        64.60        42.280  1.021210e+11
# 3        2.499560            3.29       125.86        60.050  1.813863e+11
# 4        1.714470            5.44       162.60       114.820  9.876586e+10
#
#          EBITDA  Price/Sales  Price/Book  \
# ...

# %%
# sns.barplot(data=df, x='Dividend Yield', y='Sector', hue='Sector')
# plt.show()

# %%
sns.boxplot(data=df, x='Dividend Yield', y='Sector', hue='Sector')
plt.show()

# %%
# -----------------------------------------------------------------------------------------------------------------

# %%
# sns.scatterplot(data=df, x='EBITDA', y='Dividend Yield', hue='Sector')
# plt.show()

# %%
sns.barplot(data=df, x='EBITDA', y='Sector', hue='Sector')
plt.show()

# %%
sns.boxplot(data=df, x='EBITDA', y='Sector', hue='Sector')
plt.show()

# %%
sns.scatterplot(data=df, x='EBITDA', y='Market Cap', hue='Sector')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                    Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# Price           1.000000        0.194761       -0.244630        0.591061
# Price/Earnings  0.194761        1.000000       -0.181330        0.004570
# Dividend Yield -0.244630       -0.181330        1.000000       -0.077235
# Earnings/Share  0.591061        0.004570       -0.077235        1.000000
# 52 Week Low     0.995076        0.185356       -0.244426        0.588595
# 52 Week High    0.982787        0.144700       -0.207953        0.604894
# Market Cap      0.406474        0.131381       -0.021794        0.194063
# EBITDA          0.180321        0.002950        0.126133        0.180583
# Price/Sales     0.181625        0.188558       -0.077724       -0.036178
# Price/Book      0.023637        0.000366        0.089369        0.032254
#
#                 52 Week Low  52 Week High  Market Cap    EBITDA  Price/Sales  \
# Price              0.995076      0.982787    0.406474  0.180321     0.181625
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)
# Out:
# <Axes: >

# %%
# fig, axs = plt.subplots(nrows=3)
# sns.heatmap(df.corr(numeric_only=True), annot = True, ax = axs[0])
# sns.heatmap(df.corr(numeric_only=True, method = "spearman"), annot = True, ax = axs[1])
# sns.heatmap(df.corr(numeric_only=True, method = "kendall"), annot = True, ax = axs[2])

# %% [markdown]
# El dataset usado contiene numerosos indicadores financieros de las compañías que componen el S&P 500. Se descargó de Kaggle del siguiente enlace: https://www.kaggle.com/datasets/paytonfisher/sp-500-companies-with-financial-information.
#
# Para el ejercicio "Taller 3. Comparte tu Análisis bivariado", escogí los campos 'EBITDA', 'Dividend Yield' y 'Sector'. El primero corresponde a las ganancias de una empresa antes de descontar el pago de intereses, impuestos, depreciación y amortización. El EBITDA se usa como medida de rentabilidad de una empresa a nivel operativo, ya que no incluye el efecto de los costos por deudas, impuestos y mantenimiento de activos. El segundo se refiere a la razón dividendo/precio, la cual es el dividendo pagado por una acción dividido por el precio de una acción. Por último, se consideró el campo 'Sector' para analizar la relación bivariada en los diferentes sectores de la economía de los que hacen parte las empresas analizadas.
#
# Análisis bivariado:
# De la matriz de correlaciones calculada utilizando el método por defecto de Pearson, se puede ver que la relación entre el EBITDA y el Dividend Yield, aunque es positiva, es débil (0.126133). Esto indica que aunque las ganancias operativas de una empresa sean mayores esto no se va a traducir en un aumento de la rentabilidad de los dividendos significativo (dividendo por acción/precio por acción). Haciendo un análisis univariado sobre los campos EBITDA y Dividend Yield y diferenciando entre los sectores económicos de los que hacen parte las empresas, podemos ver que el sector de Servicios de Telecomunicaciones tiene un EBITDA y rentabilidad del dividendo promedio superior a otros sectores, por lo que sería aconcejable explorar más a fondo este sector ya que es el sector más atractivo para invertir a primera vista, puesto que el precio que se pague por acción va a 'rentar' más, ya que en promedio se van a recibir mayores dividendos por acción comprada.
